# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
import tensorflow as tf

pd.pandas.set_option('display.max_columns',None)

# %%
dataset = pd.read_csv('data_train3.csv')
dataset.drop(['YearRemodAdd'],axis=1,inplace=True)
dataset2 = pd.read_csv('data_train2.csv')
dataset2.drop(['YearRemodAdd'],axis=1,inplace=True)

# %%
dataset2.head()
# Out:
#    MSSubClass  MSZoning  OverallQual  RoofStyle  BsmtQual  BsmtExposure  \
# 0          60         4            7          2         3             1
# 1          20         4            6          2         3             4
# 2          60         4            7          2         3             3
# 3          70         4            7          2         2             1
# 4          60         4            8          2         3             2
#
#    HeatingQC  CentralAir  1stFlrSF  GrLivArea  BsmtFullBath  KitchenQual  \
# 0          5           1       856       1710             1            3
# 1          5           1      1262       1262             0            2
# 2          5           1       920       1786             1            3
# 3          4           1       961       1717             1            3
# 4          5           1      1145       2198             1            3
#
#    Fireplaces  FireplaceQu  GarageType  GarageFinish  GarageCars  PavedDrive  \
# ...

# %%
dataset.head()
# Out:
#    MSSubClass  MSZoning  OverallQual  RoofStyle  BsmtQual  BsmtExposure  \
# 0          60         4            7          2         3             1
# 1          20         4            6          2         3             4
# 2          60         4            7          2         3             3
# 3          70         4            7          2         2             1
# 4          60         4            8          2         3             2
#
#    HeatingQC  CentralAir  1stFlrSF  GrLivArea  BsmtFullBath  KitchenQual  \
# 0          5           1       856       1710             1            3
# 1          5           1      1262       1262             0            2
# 2          5           1       920       1786             1            3
# 3          4           1       961       1717             1            3
# 4          5           1      1145       2198             1            3
#
#    Fireplaces  FireplaceQu  GarageType  GarageFinish  GarageCars  PavedDrive  \
# ...

# %%
dataset.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'OverallQual', 'RoofStyle', 'BsmtQual',
#        'BsmtExposure', 'HeatingQC', 'CentralAir', '1stFlrSF', 'GrLivArea',
#        'BsmtFullBath', 'KitchenQual', 'Fireplaces', 'FireplaceQu',
#        'GarageType', 'GarageFinish', 'GarageCars', 'PavedDrive',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
x = dataset.iloc[:, :-1].values #take the indexes of the column/row we need to extract from dataset
y = dataset.iloc[:, -1].values
x2 = dataset2.iloc[:, :].values #take the indexes of the column/row we need to extract from dataset

# %%
x2
# Out:
# array([[60,  4,  7, ...,  2,  3,  5],
#        [20,  4,  6, ...,  2,  3,  5],
#        [60,  4,  7, ...,  2,  3,  5],
#        ...,
#        [70,  4,  7, ...,  1,  3,  5],
#        [20,  4,  5, ...,  1,  3,  5],
#        [20,  4,  5, ...,  1,  3,  5]], dtype=int64)

# %%
y
# Out:
# array([208500, 181500, 223500, ..., 266500, 142125, 147500], dtype=int64)

# %% [markdown]
# from sklearn.compose import ColumnTransformer
# from sklearn.preprocessing import OneHotEncoder
# ct = ColumnTransformer(transformers=[('encoder' , OneHotEncoder(),[2,4])], remainder='passthrough')
# x = np.array(ct.fit_transform(x))

# %% [markdown]
# from sklearn.compose import ColumnTransformer
# from sklearn.preprocessing import OneHotEncoder
# ct = ColumnTransformer(transformers=[('encoder' , OneHotEncoder(),[2,4])], remainder='passthrough')
# x2 = np.array(ct.fit_transform(x2))

# %%
x2
# Out:
# array([[60,  4,  7, ...,  2,  3,  5],
#        [20,  4,  6, ...,  2,  3,  5],
#        [60,  4,  7, ...,  2,  3,  5],
#        ...,
#        [70,  4,  7, ...,  1,  3,  5],
#        [20,  4,  5, ...,  1,  3,  5],
#        [20,  4,  5, ...,  1,  3,  5]], dtype=int64)

# %% [markdown]
# from sklearn.compose import ColumnTransformer
# from sklearn.preprocessing import OneHotEncoder
# ct = ColumnTransformer(transformers=[('encoder' , OneHotEncoder(),[44])], remainder='passthrough')
# x = np.array(ct.fit_transform(x))

# %% [markdown]
# from sklearn.compose import ColumnTransformer
# from sklearn.preprocessing import OneHotEncoder
# ct = ColumnTransformer(transformers=[('encoder' , OneHotEncoder(),[44])], remainder='passthrough')
# x2 = np.array(ct.fit_transform(x2))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# # feature scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(x_train)
# Out:
# MinMaxScaler()

# %%
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
x
# Out:
# array([[60,  4,  7, ...,  2,  3,  5],
#        [20,  4,  6, ...,  2,  3,  5],
#        [60,  4,  7, ...,  2,  3,  5],
#        ...,
#        [70,  4,  7, ...,  1,  3,  5],
#        [20,  4,  5, ...,  1,  3,  5],
#        [20,  4,  5, ...,  1,  3,  5]], dtype=int64)

# %% [markdown]
# x = np.asarray(x).astype('float32')
# y = np.asarray(y).astype('float32')
# x2 = np.asarray(x2).astype('float32')

# %%
x_train
# Out:
# array([[0.        , 0.75      , 0.88888889, ..., 0.75      , 1.        ,
#         1.        ],
#        [0.        , 0.75      , 0.44444444, ..., 0.25      , 1.        ,
#         0.8       ],
#        [0.05882353, 0.75      , 0.44444444, ..., 0.5       , 1.        ,
#         0.8       ],
#        ...,
#        [0.41176471, 0.25      , 0.55555556, ..., 0.5       , 1.        ,
#         0.8       ],
#        [0.58823529, 0.75      , 0.66666667, ..., 0.5       , 1.        ,
#         0.8       ],
#        [0.23529412, 0.75      , 0.66666667, ..., 0.5       , 1.        ,
#         0.8       ]])

# %%
ann = tf.keras.models.Sequential()

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=1))

# %%
ann.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
ann.fit(x_train, y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 37/37 [==============================] - 0s 1ms/step - loss: 38848806912.0000
# Epoch 2/100
# 37/37 [==============================] - 0s 1ms/step - loss: 38848737280.0000
# Epoch 3/100
# 37/37 [==============================] - 0s 1ms/step - loss: 38848589824.0000
# Epoch 4/100
# 37/37 [==============================] - 0s 1ms/step - loss: 38848237568.0000
# Epoch 5/100
# 37/37 [==============================] - 0s 1ms/step - loss: 38847565824.0000
# Epoch 6/100
# 37/37 [==============================] - 0s 1ms/step - loss: 38846803968.0000
# Epoch 7/100
# 37/37 [==============================] - 0s 1ms/step - loss: 38845755392.0000
# Epoch 8/100
# 37/37 [==============================] - 0s 844us/step - loss: 38844084224.0000
# Epoch 9/100
# 37/37 [==============================] - 0s 1ms/step - loss: 38841610240.0000
# Epoch 10/100
# 37/37 [==============================] - 0s 844us/step - loss: 38838476800.0000
# Epoch 11/100
# ...

# %%
Y_pred = ann.predict(x_test)

# %%
Y_pred3 = ann.predict(x_train)

# %%
Y_pred2 = ann.predict(x2)

# %%
Y_pred2
# Out:
# array([[3377728.2],
#        [3267396.8],
#        [3561912.2],
#        ...,
#        [4610696.5],
#        [2796093.8],
#        [3240878.2]], dtype=float32)

# %%
Y_pred2 = Y_pred2.flatten()

# %%
Y_pred
# Out:
# array([[15082.445 ],
#        [12947.535 ],
#        [12504.723 ],
#        [15556.427 ],
#        [10075.495 ],
#        [ 9323.006 ],
#        [14930.51  ],
#        [11214.146 ],
#        [19146.943 ],
#        [13343.77  ],
#        [16527.799 ],
#        [11184.673 ],
#        [15401.246 ],
#        [13048.245 ],
#        [11838.527 ],
#        [11876.389 ],
#        [15419.336 ],
#        [10274.6455],
#        [11729.8545],
#        [14433.389 ],
#        [10471.058 ],
#        [16290.217 ],
#        [10451.89  ],
#        [14233.178 ],
#        [14340.251 ],
#        [13072.588 ],
#        [13434.308 ],
#        [10570.167 ],
#        [17848.945 ],
#        [ 9657.449 ],
#        [11566.325 ],
#        [14941.529 ],
#        [14980.239 ],
#        [16295.774 ],
#        [17970.174 ],
#        [14797.777 ],
#        [18178.502 ],
#        [10831.501 ],
#        [16168.025 ],
#        [17009.326 ],
#        [14718.569 ],
#        [12395.182 ],
#        [15850.393 ],
# ...

# %%
y_test
# Out:
# array([200624, 133000, 110000, 192000,  88000,  85000, 282922, 141000,
#        745000, 148800, 208900, 136905, 225000, 123000, 119200, 145000,
#        190000, 123600, 149350, 155000, 166000, 144500, 110000, 174000,
#        185000, 168000, 177500,  84500, 320000, 118500, 110000, 213000,
#        156000, 250000, 372500, 175000, 277500, 112500, 263000, 325000,
#        243000, 130000, 164990, 280000, 403000, 119000, 125000, 128200,
#        172500,  84900, 412500, 156000, 167900, 100000, 275000, 123000,
#        132000, 239900, 139000, 115000, 137500, 135000, 134450, 180500,
#        193500, 156500, 132000, 224500, 139000, 225000, 188500, 118000,
#         82000, 392000, 112000, 248900, 134500,  79500, 320000, 158000,
#        140000, 136500, 107500, 145000, 200500, 185000, 105000, 202665,
#        186000, 136000, 200500, 190000, 187500, 200000, 172500, 157000,
#        213000, 185000, 124500, 162900, 260000, 198500, 120000, 159500,
# ...

# %%
y_train
# Out:
# array([314813, 109500, 163500, ..., 112000, 234000, 221000], dtype=int64)

# %%
y_test
# Out:
# array([200624, 133000, 110000, 192000,  88000,  85000, 282922, 141000,
#        745000, 148800, 208900, 136905, 225000, 123000, 119200, 145000,
#        190000, 123600, 149350, 155000, 166000, 144500, 110000, 174000,
#        185000, 168000, 177500,  84500, 320000, 118500, 110000, 213000,
#        156000, 250000, 372500, 175000, 277500, 112500, 263000, 325000,
#        243000, 130000, 164990, 280000, 403000, 119000, 125000, 128200,
#        172500,  84900, 412500, 156000, 167900, 100000, 275000, 123000,
#        132000, 239900, 139000, 115000, 137500, 135000, 134450, 180500,
#        193500, 156500, 132000, 224500, 139000, 225000, 188500, 118000,
#         82000, 392000, 112000, 248900, 134500,  79500, 320000, 158000,
#        140000, 136500, 107500, 145000, 200500, 185000, 105000, 202665,
#        186000, 136000, 200500, 190000, 187500, 200000, 172500, 157000,
#        213000, 185000, 124500, 162900, 260000, 198500, 120000, 159500,
# ...

# %%
import csv
with open('export3.csv','w',newline='') as csvfile:
    fieldnames=['Id','SalePrice']
    thewriter=csv.DictWriter(csvfile,fieldnames=fieldnames)
    thewriter.writeheader() 
    count = 1460
    for i in range(len(Y_pred2)):
        count += 1
        thewriter.writerow({'Id':count, 'SalePrice':Y_pred2[i]})
